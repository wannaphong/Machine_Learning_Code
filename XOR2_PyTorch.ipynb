# %% [markdown]
# <a href="https://colab.research.google.com/github/wannaphongcom/Machine_Learning_Code/blob/master/XOR2_PyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
# Defining input size, hidden layer size, output size and batch size respectively
n_in, n_h, n_out, batch_size = 2, 8, 1, 10

# %%
x=torch.tensor([[0,0],[0,1],[1,0],[1,1]]).float()
y=torch.tensor([[0],[1],[1],[0]]).float()

# %%
print(x)
# Out:
# tensor([[0., 0.],
#         [0., 1.],
#         [1., 0.],
#         [1., 1.]])

# %%
model = nn.Sequential(nn.Linear(n_in, n_h),
 nn.ReLU(),
 nn.Linear(n_h, n_out),
 nn.Sigmoid())

# %%
print(model)
# Out:
# Sequential(
#   (0): Linear(in_features=2, out_features=8, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=8, out_features=1, bias=True)
#   (3): Sigmoid()
# )

# %%
# Construct the loss function
criterion = nn.MSELoss()

# %%
# Construct the optimizer (Stochastic Gradient Descent in this case)
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# %%
# Gradient Descent
for epoch in range(5000):
  # Forward pass: Compute predicted y by passing x to the model
  y_pred = model(x)
  # Compute and print loss
  loss = criterion(y_pred,y)
  print('epoch: ', str(epoch+1),' loss: ', loss.item())
  # Zero gradients, perform a backward pass, and update the weights.
  optimizer.zero_grad()
  # perform a backward pass (backpropagation)
  loss.backward()
  # Update the parameters
  optimizer.step()
# Out:
# epoch:  1  loss:  0.26560965180397034
# epoch:  2  loss:  0.2648575007915497
# epoch:  3  loss:  0.26413169503211975
# epoch:  4  loss:  0.26343122124671936
# epoch:  5  loss:  0.2627550959587097
# epoch:  6  loss:  0.26210230588912964
# epoch:  7  loss:  0.26147186756134033
# epoch:  8  loss:  0.2608628571033478
# epoch:  9  loss:  0.26027432084083557
# epoch:  10  loss:  0.2597053349018097
# epoch:  11  loss:  0.2591550648212433
# epoch:  12  loss:  0.25862258672714233
# epoch:  13  loss:  0.25810712575912476
# epoch:  14  loss:  0.25764018297195435
# epoch:  15  loss:  0.2572014629840851
# epoch:  16  loss:  0.25677797198295593
# epoch:  17  loss:  0.2563689053058624
# epoch:  18  loss:  0.2559735178947449
# epoch:  19  loss:  0.2555910348892212
# epoch:  20  loss:  0.25522083044052124
# epoch:  21  loss:  0.2548622190952301
# epoch:  22  loss:  0.2545146048069
# epoch:  23  loss:  0.2541773319244385
# epoch:  24  loss:  0.2538498044013977
# epoch:  25  loss:  0.2535315155982971
# ...

# %%
with torch.no_grad():
  print(model(torch.tensor([[0,1]]).float()))
# Out:
# tensor([[0.9751]])
